# %% [markdown]
# <a href="https://colab.research.google.com/github/inefable12/Exploracion_insilico_2024/blob/main/Pre_optimizacion_bd_catechol_83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pre-optimización con Open Babel

# %%
# !ls
# Out:
# db_catechol1.csv  sample_data

# %%
# !apt-get -qq install -y openbabel

# %%
# !obabel -i smi db_catechol1.csv -o sdf --gen3D > output.sdf
# Out:
# 83 molecules converted

# %%
# !grep WARNING output.sdf

# %%
# !obabel -i sdf output.sdf -O opt.xyz --minimize --sd --steps 1000 --ff MMFF94 --log -h -m
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#
# A T O M   T Y P E S
#
# IDX	TYPE	RING
# 1	37	AR
# 2	37	AR
# 3	37	AR
# 4	37	AR
# 5	37	AR
# 6	37	AR
# 7	3	NO
# 8	7	NO
# 9	6	NO
# 10	6	NO
# 11	6	NO
# 12	5	NO
# 13	5	NO
# 14	5	NO
# 15	24	NO
# 16	29	NO
# 17	29	NO
#
# F O R M A L   C H A R G E S
#
# IDX	CHARGE
# 1	0.000000
# 2	0.000000
# 3	0.000000
# 4	0.000000
# 5	0.000000
# 6	0.000000
# 7	0.000000
# 8	0.000000
# 9	0.000000
# 10	0.000000
# 11	0.000000
# 12	0.000000
# 13	0.000000
# 14	0.000000
# 15	0.000000
# 16	0.000000
# 17	0.000000
#
# P A R T I A L   C H A R G E S
#
# IDX	CHARGE
# 1	-0.150000
# 2	-0.150000
# 3	0.082500
# 4	0.082500
# 5	-0.150000
# 6	0.086200
# 7	0.633800
# 8	-0.570000
# 9	-0.650000
# 10	-0.532500
# 11	-0.532500
# 12	0.150000
# 13	0.150000
# 14	0.150000
# 15	0.500000
# 16	0.450000
# 17	0.450000
#
# S E T T I N G   U P   C A L C U L A T I O N S
#
# SETTING UP BOND CALCULATIONS...
# SETTING UP ANGLE & STRETCH-BEND CALCULATIONS...
# ...

# %%
# !mkdir resultado

# %%
# !mv *.xyz resultado

# %%
# !ls resultado
# Out:
# opt10.xyz  opt1.xyz   opt29.xyz  opt38.xyz  opt47.xyz  opt56.xyz  opt65.xyz  opt74.xyz	opt83.xyz
# opt11.xyz  opt20.xyz  opt2.xyz	 opt39.xyz  opt48.xyz  opt57.xyz  opt66.xyz  opt75.xyz	opt8.xyz
# opt12.xyz  opt21.xyz  opt30.xyz  opt3.xyz   opt49.xyz  opt58.xyz  opt67.xyz  opt76.xyz	opt9.xyz
# opt13.xyz  opt22.xyz  opt31.xyz  opt40.xyz  opt4.xyz   opt59.xyz  opt68.xyz  opt77.xyz
# opt14.xyz  opt23.xyz  opt32.xyz  opt41.xyz  opt50.xyz  opt5.xyz   opt69.xyz  opt78.xyz
# opt15.xyz  opt24.xyz  opt33.xyz  opt42.xyz  opt51.xyz  opt60.xyz  opt6.xyz   opt79.xyz
# opt16.xyz  opt25.xyz  opt34.xyz  opt43.xyz  opt52.xyz  opt61.xyz  opt70.xyz  opt7.xyz
# opt17.xyz  opt26.xyz  opt35.xyz  opt44.xyz  opt53.xyz  opt62.xyz  opt71.xyz  opt80.xyz
# opt18.xyz  opt27.xyz  opt36.xyz  opt45.xyz  opt54.xyz  opt63.xyz  opt72.xyz  opt81.xyz
# opt19.xyz  opt28.xyz  opt37.xyz  opt46.xyz  opt55.xyz  opt64.xyz  opt73.xyz  opt82.xyz

# %%
# !zip -r bd_catechol3D.zip resultado
# Out:
#   adding: resultado/ (stored 0%)
#   adding: resultado/opt73.xyz (deflated 71%)
#   adding: resultado/opt38.xyz (deflated 69%)
#   adding: resultado/opt26.xyz (deflated 70%)
#   adding: resultado/opt11.xyz (deflated 70%)
#   adding: resultado/opt62.xyz (deflated 69%)
#   adding: resultado/opt61.xyz (deflated 71%)
#   adding: resultado/opt49.xyz (deflated 69%)
#   adding: resultado/opt32.xyz (deflated 70%)
#   adding: resultado/opt50.xyz (deflated 70%)
#   adding: resultado/opt23.xyz (deflated 70%)
#   adding: resultado/opt41.xyz (deflated 70%)
#   adding: resultado/opt53.xyz (deflated 70%)
#   adding: resultado/opt29.xyz (deflated 70%)
#   adding: resultado/opt72.xyz (deflated 70%)
#   adding: resultado/opt2.xyz (deflated 70%)
#   adding: resultado/opt44.xyz (deflated 70%)
#   adding: resultado/opt30.xyz (deflated 70%)
#   adding: resultado/opt55.xyz (deflated 69%)
#   adding: resultado/opt75.xyz (deflated 70%)
#   adding: resultado/opt71.xyz (deflated 69%)
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd resultado
# Out:
# /content/resultado

# %%
# !obabel -i xyz *.xyz -o pdbqt -O _.pdbqt -m
# Out:
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is opt26.xyz)
#
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is opt31.xyz)
#
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is opt32.xyz)
#
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is opt33.xyz)
#
# ...
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is opt35.xyz)
#
# 83 molecules converted
# 83 files output. The first is _opt10.pdbqt

# %%
# !mkdir resultado_pdbqt_falta26_31_32_33_35

# %%
# !mv *pdbqt resultado_pdbqt_falta26_31_32_33_35

# %%
# !zip -r resultado_pdbqt_falta26_31_32_33_35.zip resultado_pdbqt_falta26_31_32_33_35
# Out:
#   adding: resultado_pdbqt_falta26_31_32_33_35/ (stored 0%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt58.pdbqt (deflated 75%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt79.pdbqt (deflated 76%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt80.pdbqt (deflated 71%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt45.pdbqt (deflated 77%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt40.pdbqt (deflated 77%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt13.pdbqt (deflated 75%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt6.pdbqt (deflated 75%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt25.pdbqt (deflated 76%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt22.pdbqt (deflated 76%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt37.pdbqt (deflated 74%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt49.pdbqt (deflated 77%)
#   adding: resultado_pdbqt_falta26_31_32_33_35/_opt75.pdbqt (deflated 74%)
# ...
